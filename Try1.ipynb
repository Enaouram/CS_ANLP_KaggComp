# %%
import pandas as pd
import json
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import re

# Load the training data from JSON
with open('train.json', 'r') as file:
    train_data = json.load(file)

# Convert the training data from JSON to a DataFrame
categories = []
texts = []
for category, text_list in train_data.items():
    for text in text_list:
        categories.append(category)
        texts.append(text)

train_df = pd.DataFrame({'Text': texts, 'Category': categories})

# %%
train_df
# Out:
#                                                  Text       Category
# 0   The mayor announced a new initiative to improv...       Politics
# 1   The senator is facing criticism for her stance...       Politics
# 2   The upcoming election has sparked intense deba...       Politics
# 3   Regular exercise and a balanced diet are key t...         Health
# 4   The World Health Organization has issued new g...         Health
# 5   A new study reveals the benefits of meditation...         Health
# 6   The stock market saw a significant drop follow...        Finance
# 7   Investing in real estate can be a profitable v...        Finance
# 8   The company's profits have doubled since the l...        Finance
# 9   Visiting the Grand Canyon is a breathtaking ex...         Travel
# 10  The tourism industry has been severely impacte...         Travel
# 11  Backpacking through Europe is a popular choice...         Travel
# 12  The new restaurant in town offers a fusion of ...           Food
# ...

# %%
# Function to clean text data
def simple_clean_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\d+', '', text)  # Remove numbers
    return text

# Apply the cleaning function to training data
train_df['Cleaned_Text'] = train_df['Text'].apply(simple_clean_text)

# TF-IDF Vectorization for training data
vectorizer = TfidfVectorizer(max_features=5000)
X_train_tfidf = vectorizer.fit_transform(train_df['Cleaned_Text'])

# Label Encoding for training data
encoder = LabelEncoder()
y_train_encoded = encoder.fit_transform(train_df['Category'])

# Train a Logistic Regression model
model = LogisticRegression(max_iter=1000)
model.fit(X_train_tfidf, y_train_encoded)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# Now I'm thinking about 3 approaches :
#
# - Manual Labeling
# - Clustering for labeling
# - Cosine similarity with the classes and assign the sample to the closest label

# %% [markdown]
# Any other suggestions ?
